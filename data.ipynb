# %%
# IMports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Cell 2: Load the CSV file into a DataFrame
df = pd.read_csv('data.csv')

# %%
# Display the first few rows to confirm loading
df.head()
# Out:
#    Year  Foreign direct investment, net inflows (% of GDP)  \
# 0  2000                                           8.332984
# 1  2001                                           9.460785
# 2  2002                                          11.187463
# 3  2003                                           7.149643
# 4  2004                                           7.515648
#
#    Domestic credit to private sector (% of GDP)  Broad money (% of GDP)  \
# 0                                     31.904543               45.870280
# 1                                     47.412880               48.756359
# 2                                     47.150274               48.337036
# 3                                     39.338726               38.380371
# 4                                     37.961165               38.921651
#
#    Net Foreigh Assets (% of GDP)
# 0                      21.169038
# 1                      24.617408
# 2                      25.915725
# 3                      22.917556
# ...

# %%
# Cell 3: Basic information about the dataset
print("--- Dataset Info ---")
df.info() # Data types, non-null counts, memory usage
print("\n--- Dataset Shape (Rows, Columns) ---")
print(df.shape)
print("\n--- Column Names ---")
print(df.columns.tolist())
# Out:
# --- Dataset Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Year                                               26 non-null     int64
#  1   Foreign direct investment, net inflows (% of GDP)  26 non-null     float64
#  2   Domestic credit to private sector (% of GDP)       26 non-null     float64
#  3   Broad money (% of GDP)                             26 non-null     float64
#  4   Net Foreigh Assets (% of GDP)                      26 non-null     float64
# dtypes: float64(4), int64(1)
# memory usage: 1.1 KB
#
# --- Dataset Shape (Rows, Columns) ---
# (26, 5)
#
# --- Column Names ---
# ...

# %%
# Drop the specified column in place(modifies the original DataFrame)
# df = df.drop(columns=['Net foreign assets (current LCU) ttd'])
df = df.drop(columns=['Year'])

# Verify the column has been dropped by checking the columns again
print(df.columns.tolist())
# Out:
# ['Foreign direct investment, net inflows (% of GDP)', 'Domestic credit to private sector (% of GDP)', 'Broad money (% of GDP)', 'Net Foreigh Assets (% of GDP)']

# %%
print("--- Statistical Summary (Numerical Columns) ---")
df.describe()
# Out:
# --- Statistical Summary (Numerical Columns) ---
#        Foreign direct investment, net inflows (% of GDP)  \
# count                                          26.000000
# mean                                            1.851857
# std                                             5.240546
# min                                            -7.014857
# 25%                                            -2.706502
# 50%                                             1.511992
# 75%                                             5.667322
# max                                            11.187463
#
#        Domestic credit to private sector (% of GDP)  Broad money (% of GDP)  \
# count                                     26.000000               26.000000
# mean                                      36.527205               56.427490
# std                                        6.751037               13.206229
# min                                       26.632285               36.616223
# ...

# %%
print("--- Correlation Matrix (Numerical Columns) ---")
correlation_matrix = df.select_dtypes(include='number').corr()
print(correlation_matrix)
# Out:
# --- Correlation Matrix (Numerical Columns) ---
#                                                    Foreign direct investment, net inflows (% of GDP)  \
# Foreign direct investment, net inflows (% of GDP)                                           1.000000
# Domestic credit to private sector (% of GDP)                                                0.057967
# Broad money (% of GDP)                                                                     -0.608337
# Net Foreigh Assets (% of GDP)                                                              -0.468105
#
#                                                    Domestic credit to private sector (% of GDP)  \
# Foreign direct investment, net inflows (% of GDP)                                      0.057967
# Domestic credit to private sector (% of GDP)                                           1.000000
# Broad money (% of GDP)                                                                 0.510847
# ...

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.show()
